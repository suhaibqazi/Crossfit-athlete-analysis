# %%
# import libs

import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib import style
import seaborn as sns

# %matplotlib inline 
# to display charts in jupyter notebook

# %%
pd.options.display.max_colwidth = 150

# %%
#import excel

df = pd.read_excel(r'L:\Forward\2016\13. Reporting\Analytics\Adhoc requests\Econometrics\RAW DATA Accurate\Econ_Automation\Suhaib\Classifications_ThursdaytoCheck.xlsx', sheetname = 'Sheet1')

# %% [markdown]
# df = pd.read_excel(r'L:\Forward\2016\13. Reporting\Analytics\Adhoc requests\Econometrics\RAW DATA Accurate\Tableau Inputs - Final versions\Planning to review\MMS+ Extract 09082017 review all (new rows from 93).xlsx', sheetname = 'Sheet1')

# %%
df_UIDs = pd.read_excel(r'C:\Users\suhaib.qazi\Desktop\UIDs.xlsx', sheetname = 'Sheet1')

# %%
df
# Out:
#                                                                          Campaign  \
# 0                                    ..._O2_BAUDepecheMode_Announce_TW_CPLC_01840
# 1                                      ..._O2_BAUDepecheMode_OnSale_TW_CPLC_01840
# 2                                       ..._O2_BAUJPCooper_Announce_TW_CPLC_01840
# 3                                         ..._O2_BAUJPCooper_OnSale_TW_CPLC_01840
# 4                                  ..._O2_BAUMachineGunKelly_OnSale_TW_CPLC_01840
# 5                                          ..._O2_BAUNelly_Announce_TW_CPLC_01840
# 6                                            ..._O2_BAUNelly_OnSale_TW_CPLC_01840
# 7                                          ..._O2_BAUTicketsEdSheeran_OnSale_CPLC
# 8                                         ..._O2_BAUTicketsEdSheeran_PreSale_CPLC
# 9                         1701GB153520_O2_Jan Sales_Phase2_PAYM_TechInterests_CPO
# ...

# %% [markdown]
# Combine different decription columns for search. Tried loops, but different columns produced different results,
# hence better to join into one so that IF statements can be applied

# %%
df['combined']=df['Campaign'].astype(str)+'_'+df['Placement'].astype(str)+'_'+df['Campaign_Classification'].astype(str)

# %%
cols = list(df)

# %%
cols.insert(0, cols.pop(cols.index('combined')))

# %%
df = df.ix[:, cols]
# Out:
# C:\Users\suhaib.qazi\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
########exceptions!
t5_Jan = ['jan'] # high priority

t5_brand_o2travel = ['travel'] #lower priority - Brand
t6_trading_travel = ['travelrow'] #higher priority - Trading Bolt On
t1_bau = ['bau'] #low priority. Fill in o2_bau first
t6_tablet = ['tablet'] #low priority - do not search in placement!
t6_smartphone_launch = ['smartphone'] #all capitalised, no other word = launch
t4_sale = ['sale'] #low priority
t5_priority = ['priority'] #low Tier
#4G v 4G Sim!

# %%
#############################################################################################
#Brand


####Tier 5s and grouped Tier 4

#Love

t5_weartherose = ['6nation','sixnation','rugby','weartherose']
t5_warchild = ['warchild']
t5_prioritywalk = ['prioritywalk','starwars']
t5_LiveExperiences = ['birthday','liveexperience','followtherabbit']

grpd_t4_love = t5_prioritywalk+t5_weartherose+t5_warchild+t5_LiveExperiences


#More Perks

t5_prioritytickets = ['prioritytick','o2_bau','o2bau','o2_t1','o2priority']
t5_thankyou = ['thankyou']
t5_paygrewards = ['paygrewards']
t5_addedvalueoffer = ['addedvalueoffer','avo']


grped_t4_moreperks = t5_prioritytickets+t5_paygrewards+t5_thankyou+t5_addedvalueoffer

#More Services

t5_myo2 = ['myo2','my02']
t5_myo2bus = ['myo2busin','o2_busin']
t5_clickandcollect = ['click&collect','clickandcollect']
t5_gurus = ['guru']
t5_nspcc = ['nspcc']
t5_o2learn = ['o2_learn','o2learn']
t5_gothinkbig = ['gothink']
t5_o2touch = ['o2_touch','o2touch']
t5_no1cs = ['no1cs','no1cust','noonecus']

grped_t4_moreservices = t5_myo2+t5_myo2bus+t5_clickandcollect+t5_gurus+t5_nspcc+t5_o2learn+t5_gothinkbig+t5_o2touch+t5_no1cs


#More Flexibility

t5_uswitch = ['uswitch']
t5_refresh = ['moreflexibilityrefresh']
t5_recycle = ['recycle']
t5_pre_loved = ['gbo','prelove','pre-love']
t5_digitialproducts = ['digitalproducts']
t5_businessessentials = ['bsuinessessentials']
t5_30dayrolling = ['rollingcontract']


grped_t4_moreflexibility = t5_uswitch+t5_refresh+t5_recycle+t5_pre_loved+t5_digitialproducts+t5_businessessentials+t5_30dayrolling

#More Connected

t5_Wifi = ['wifihot']
t5_4G_drive = ['o2drive','brandsummer']
t5_o2home = ['home']
#o2 travel

grped_t4_moreconnected = t5_Wifi+t5_4G_drive+t5_o2home

#Multi Message

t4_multi_message = ['multimessage','multi-message']

grped_t4_multi_message = t4_multi_message


###Tier 1

tier1_brand = ['family','ethos','oops','followtherabbit']

grped_t1_Brand = tier1_brand+grpd_t4_love+grped_t4_moreperks+grped_t4_moreservices+grped_t4_moreflexibility+grped_t4_moreconnected+grped_t4_multi_message

# %%
#############################################################################################
#Trading



######Tier 5 and 4 

##Tactical
t6_tactical_paym = ['50%','doubled','tact','speedtorefresh']

grped_t4_tactical = t6_tactical_paym


##Launch
t4_Launch = ['launch','samsungdream']
t4_launch_phones = ['5T']

grped_t4_launch = t4_Launch+t4_launch_phones


##Seasonal
t5_xmas = ['xmas','christmas']
t5_flash_sale = ['flagshipsale']
t5_blackfriday = ['cyberweek','blackfriday']

t4_seasonal = ['easter','uni']

grped_t4_seasonal = t5_xmas+t5_flash_sale+t5_blackfriday+t4_seasonal

##Always On
t4_alwayson = ['alwayson']




###Tier 1

grped_t1_Trading = grped_t4_tactical+grped_t4_launch+grped_t4_seasonal+grped_t4_alwayson


######Tier 6

t6_Tablet_MBB = ['mbb','broadband','ipad','samsung tab'] 


payg = ['freesim','pandg','p&g','payasyougo','payandgo','bundle','international','intsim','simo','brandsim']
paym =['paym','handset','o2pure','o2shop']
payg_sim=['newtarriff','businesssim','O2simplicity']



Android_handsets = ['samsung','xperia','oneplus','android']
iphone_handsets = ['iphone','apple']
handset_general = ['handset','blackberry','lumia']

t6_smartwatch = ['smartwatch','fitbit','moto360']

t6_trading_grouped = t6_Tablet_MBB+payg+paym+payg_sim+Android_handsets+iphone_handsets+handset_general

# %% [markdown]
# RULES

# %%
def tier1_rules(raw_Df):
    val=''  
    if any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_Jan):
        val='Trading'
        
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in grped_t1_Brand):
        val='Brand'        
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in grped_t1_Trading):
        val='Trading'
        
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t1_bau):
        val='Trading'      
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t6_trading_grouped):
        val='Trading'
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t6_trading_travel):
        val='Trading'
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t6_tablet):
        val='Trading'
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t6_smartphone_launch):
        val='Trading'
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t4_sale):
        val='Trading'
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_priority):
        val='Brand'        
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in ['brand']):
        val='Brand'
    else: val = ''

    return val

# %%
df.loc[:,'Tier 1_New']=df.apply(tier1_rules,axis=1)

# %%
df['Tier 1_New'].value_counts()
# Out:
# Trading    12618
# Brand       1361
#              129
# Name: Tier 1_New, dtype: int64

# %%
 #TIER 4
######################################


def tier4_rules(raw_Df):
    val=''  
      
    if any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_Jan):
        val='Seasonal Event' 
        
        
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in grpd_t4_love):
        val='Love' 
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in grped_t4_moreperks):
        val='More Perks'
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in grped_t4_moreservices):
        val='More Services'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in grped_t4_moreflexibility):
        val='More flexibility'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in grped_t4_moreconnected):
        val='More Connected'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in grped_t4_multi_message):
        val='Multi-Message'
        
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in grped_t4_tactical):
        val='Tactical' 
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in grped_t4_launch):
        val='Launch'
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in grped_t4_seasonal):
        val='Seasonal Event'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in grped_t4_alwayson):
        val='Always On'    
        

    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t6_trading_grouped):
        val='Always On'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t1_bau):
        val='Always On'    
    else: val=''
            
    return val

# %%
df.loc[:,'Tier 4_New']=df.apply(tier4_rules,axis=1)

# %%
 #TIER 5
######################################


def tier5_rules(raw_Df):
    val=''  
      
    if any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_Jan):
        val='' 
        
        
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_weartherose):
        val='#weartherose' 
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_warchild):
        val='Warchild'
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_LiveExperiences):
        val='Live Experiences'
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_prioritywalk):
        val='Priority Walk'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_prioritytickets):
        val='Priority Tickets'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_thankyou):
        val='Thank You'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_paygrewards):
        val='PAYG Rewards'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_addedvalueoffer):
        val='Added Value Offers'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_myo2):
        val='My O2'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_myo2bus):
        val='My O2 Business'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_clickandcollect):
        val='Click & Collect'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_gurus):
        val='Gurus'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_nspcc):
        val='NSPCC'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_o2learn):
        val='O2 Learn'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_gothinkbig):
        val='Go Think Big'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_o2touch):
        val='O2 Touch'
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_no1cs):
        val='No1 Customer Service'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_uswitch):
        val='Uswitch'
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_refresh):
        val='Refresh'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_recycle):
        val='Recycle'
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_pre_loved):
        val='GBO & Pre-loved'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_digitialproducts):
        val='Digital Products'
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_businessessentials):
        val='Business Essentials'    
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_30dayrolling):
        val='30 Day rolling contract for Apps'
       
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_Wifi):
        val='Wifi Hotspots' 
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_4G_drive):
        val='4G O2 Drive' 
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_o2home):
        val='O2 Home'        
        
        
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in t5_brand_o2travel):
        val='O2 Travel'           
    elif any(word in str(raw_Df['combined']).lower().replace(" ", "") for word in tier5_priority):
        val='Priority'    
        
        
    else: val=''
            
    return val

# %%
df.loc[:,'Tier 5_New']=df.apply(tier5_rules,axis=1)

# %% [markdown]
# df['Tier 5_New'].value_counts()

# %%
df
# Out:
#                                                                                  combined  \
# 0                                    ..._O2_BAUDepecheMode_Announce_TW_CPLC_01840_nan_nan
# 1                                      ..._O2_BAUDepecheMode_OnSale_TW_CPLC_01840_nan_nan
# 2                                       ..._O2_BAUJPCooper_Announce_TW_CPLC_01840_nan_nan
# 3                                         ..._O2_BAUJPCooper_OnSale_TW_CPLC_01840_nan_nan
# 4                                  ..._O2_BAUMachineGunKelly_OnSale_TW_CPLC_01840_nan_nan
# 5                                          ..._O2_BAUNelly_Announce_TW_CPLC_01840_nan_nan
# 6                                            ..._O2_BAUNelly_OnSale_TW_CPLC_01840_nan_nan
# 7                                          ..._O2_BAUTicketsEdSheeran_OnSale_CPLC_nan_nan
# 8                                         ..._O2_BAUTicketsEdSheeran_PreSale_CPLC_nan_nan
# ...

# %%
df_tier1_nonmatch = df[~(df['Tier 1_New'].str.lower() == df['Tier 1'].str.lower())]
df_tier1_nonmatch.to_csv(r'C:\Users\suhaib.qazi\Desktop\tier1nomatch.csv', sep=',')

# %%
df_tier1_null = df[df['Tier 1_New'].isin([''])]
df_tier1_null.to_csv(r'C:\Users\suhaib.qazi\Desktop\tier1nulls.csv', sep=',')

# %%
df_tier5_nonmatch = df[~(df['Tier 5_New'].str.lower() == df['Tier 5'].str.lower())]
df_tier5_nonmatch.to_csv(r'C:\Users\suhaib.qazi\Desktop\tier5nomatch.csv', sep=',')

# %%
df_tier1_nonmatch
# Out:
#                                                            Campaign  \
# 64                   ..._O2_PrecisionJuly_ClickandCollect_CPO_06439
# 65                   ..._O2_PrecisionJune_ClickandCollect_CPO_06439
# 67                 ..._O2_ResignExtension(PrecisionApril)_CPO_06439
# 81         10154180214091254-UK_O2_Users-20170302-20170303-manual_0
# 84             1604GB96578&1701GB164422_O2_ResignCAV3(feb)_PPLA_CPO
# 91             1701GB151081_O2_ResignExtension(Precision)_CPO_06439
# 198                            1702GB167612_O2_SMBEnterpriseV2_CPLC
# 199                  1702GB167612_O2_SMBEnterpriseV3(upweight)_CPLC
# 200            1702GB167612_O2_SMBEnterpriseV4(upweight)(13.5)_CPLC
# 367             1704GB174367_O2_IdomooPrecisionAprilV5_FB_CPO_50591
# 400         1705GB182262_O2_ResignExtension(PrecisionMay)_CPO_06439
# 403                      1705GB184046_O2_DataUpsell_PPLA_CPLC_06439
# 433                                 1706GB181050_O2_LGG6_CPLC_06559
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='RdYlGn')

# %%
df2[['Campaign','Placement']]
# Out:
#                                                                          Campaign  \
# 0                                    ..._O2_BAUDepecheMode_Announce_TW_CPLC_01840
# 1                                      ..._O2_BAUDepecheMode_OnSale_TW_CPLC_01840
# 2                                       ..._O2_BAUJPCooper_Announce_TW_CPLC_01840
# 3                                         ..._O2_BAUJPCooper_OnSale_TW_CPLC_01840
# 4                                  ..._O2_BAUMachineGunKelly_OnSale_TW_CPLC_01840
# 5                                          ..._O2_BAUNelly_Announce_TW_CPLC_01840
# 6                                            ..._O2_BAUNelly_OnSale_TW_CPLC_01840
# 7                                          ..._O2_BAUTicketsEdSheeran_OnSale_CPLC
# 8                                         ..._O2_BAUTicketsEdSheeran_PreSale_CPLC
# 9                         1701GB153520_O2_Jan Sales_Phase2_PAYM_TechInterests_CPO
# ...

# %%
df_tier1_nonmatch.loc[:,'Tier 4_New']=df_tier1_null.apply(tier4_rules,axis=1)
# Out:
# C:\Users\suhaib.qazi\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:337: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\suhaib.qazi\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df_tier1_nonmatch
# Out:
#                                                            Campaign  \
# 64                   ..._O2_PrecisionJuly_ClickandCollect_CPO_06439
# 65                   ..._O2_PrecisionJune_ClickandCollect_CPO_06439
# 67                 ..._O2_ResignExtension(PrecisionApril)_CPO_06439
# 81         10154180214091254-UK_O2_Users-20170302-20170303-manual_0
# 84             1604GB96578&1701GB164422_O2_ResignCAV3(feb)_PPLA_CPO
# 91             1701GB151081_O2_ResignExtension(Precision)_CPO_06439
# 97              1701GB153515_O2_JanSales_AlwaysOn_O2Home_CPLC_06136
# 198                            1702GB167612_O2_SMBEnterpriseV2_CPLC
# 199                  1702GB167612_O2_SMBEnterpriseV3(upweight)_CPLC
# 200            1702GB167612_O2_SMBEnterpriseV4(upweight)(13.5)_CPLC
# 333                1703GB170396_O2_SimsPrecisionMarch_FB_CPLC_06439
# 367             1704GB174367_O2_IdomooPrecisionAprilV5_FB_CPO_50591
# 387              1705GB174382_O2_SIMSPrecisionAprilMay_FB_CPO_06439
# ...

# %%
 #TIER 2
######################################

def tier2_rules(raw_Df):
    val=''
      
    #print (type(raw_Df['Placement']))
    if any(word in raw_Df['Campaign'].lower() for word in Business_name):
        val = 'Business'  
    else: val = 'Consumer' 
  
    return val

# %%
#TIER 3
######################################

def tier3_rules(raw_Df):
    val='More For You'

    return val

# %%
#TIER 4
######################################

def tier4_rules(raw_Df):
    val=''
      
    if any(word in raw_Df['Campaign'].lower() for word in ['BAU']):
        val = 'Always On'
    elif any(word in raw_Df['Campaign'].lower() for word in tactical):
        val = 'Tactical'
    elif any(word in raw_Df['Campaign'].lower() for word in seasonal):
        val = 'Seasonal Event'
    elif any(word in raw_Df['Campaign'].lower() for word in ArtistName):
        val = 'More Perks'
    elif any(word in raw_Df['Campaign'].lower() for word in ['warchild','nation','priority','oops']):
        val = 'Love'
    elif any(word in raw_Df['Campaign'].lower() for word in ['nspcc','collect']):
        val = 'Love'

    return val

# %%
df2.loc[:,'Tier 1_New']=df2.apply(tier1_rules,axis=1)
df2.loc[:,'Tier 2_New']=df2.apply(tier2_rules,axis=1)
df2.loc[:,'Tier 3_New']=df2.apply(tier3_rules,axis=1)
df2.loc[:,'Tier 4_New']=df2.apply(tier4_rules,axis=1)
