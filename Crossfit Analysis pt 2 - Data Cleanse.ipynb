# %% [markdown]
# # CrossFit scraped data cleanse
#
# This notebook takes a step by step approach on how to cleanse raw data scraped from the previous notebook

# %%
import numpy as np
import pandas as pd
import re

import seaborn as sns

# %matplotlib inline 
# to display charts in jupyter notebook

# %% [markdown]
# ## 1. Import raw datascrape file

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r'C:\Users\suhaib.qazi\Desktop\cf_1a.csv', encoding = "ISO-8859-1")

# %% [markdown]
# #### 1.1 Drop itteration number - not used

# %%
df = df.drop(['Iter_Number'],axis=1)

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# #### Titles include trailing spaces - so to make it easier to work with, get rid of these

# %%
df = df.rename(columns=lambda x: x.strip())

# %% [markdown]
# ## 2. Number conversion
#
# Convert all to metric

# %% [markdown]
# ### 2.1 Convert Weightlifting figures to kg
#
# For all weight fields (olympic lifting + athlete weight) standardise into kg. If weight is in pounds, convert (mutliply by 0.45)

# %%
for col in ['Back Squat','Clean and Jerk','Deadlift','Snatch','Weight']:
#1. is it lb or kg?
    df[col+' met']=df[col].str.strip().str[-2:] 
#2. Create multipliers to convert numbers. As we are converting to kg, if measure is in kg then x1, else x0.45    
    df[col+' met'] = pd.to_numeric(df[col+' met'].replace('kg',1).replace('lb',0.453592), errors='coerce')
#3. convert measures to numbers (getting rid of metric: "kg" or "lb")
    df[col] = pd.to_numeric(df[col].str.strip().str[:-2], errors='coerce')
#4. multiple weight number by multiplier    
    df[col]=df[col]*df[col+' met']
    df[col]=df[col].round()
#5. get rid of multiplier column    
    del df[col+' met']

# %% [markdown]
# ### 2.2 Convert yearly Open position to number
#
# e.g. 250th becomes 250

# %%
#for the year columns
for col in df.iloc[:,12:22]:
#convert to string to get substrings
        df[col] = df[col].apply(str)
#convert column to numeric - after deleting last 2 characters        
        df[col] = pd.to_numeric(df[col].str.strip().str[:-2], errors='coerce').round()

# %% [markdown]
# ### 2.3 Convert Height
#
# For Heights given in feet and inches (e.g. 5'9") convert to cm (e.g. 175cm)

# %%
#get rid of " (for inches) - this will allow us to split the inches into two list elements
df['Height'] = df['Height'].str.replace('"','')

# %% [markdown]
# function to convert - if list has two elements, in is ft/inches so convert to cm
# if list is single item, get rid of 'cm'

# %%
def parse_height(x):
    feet_inches = x.split("'")
    if len(feet_inches) == 2:
        return 2.54 * (12 * int(feet_inches[0]) + float(feet_inches[1]))        
    else: return feet_inches[0][:-2] #list(map(int, results))
# Convert a height in inches to a height in centimeters

# %%
df['Height'] = pd.to_numeric(df['Height'].apply(parse_height))

# %%
#df['Height'] = pd.to_numeric(df['Height'], errors='coerce')

# %% [markdown]
# ### 2.4 Convert Minute/Sec figures to seconds

# %%
def sec_converter(x):    
    min_sec_split = x.split(":")

    if len(min_sec_split) == 2:
        return int(min_sec_split[0])*60 + int(min_sec_split[1])
    else: return min_sec_split[0]

# %%
for col in df:
    df[col] = df[col].replace('--', np.nan, regex=True)
    df[col] = df[col].replace(0, np.nan, regex=True)

# %%
for col in ['Filthy 50','Fran','Grace','Helen','Run 5k','Sprint 400m']:
    df[col] = df[col].apply(str)
    df[col] = df[col].apply(sec_converter)
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %% [markdown]
# ### 2.5 Extract gender information
#
# Extract from Division titles

# %%
def gender(s):
    val = ''

    if any(word in str(s['Division']) for word in ['Women']):
        val = 'Female'
    elif any(word in str(s['Division']) for word in ['Men']):
        val = 'Male'
    else: val = None
    return val

# %%
df['gender']=df.apply(gender,axis=1)

# %%
df
# Out:
#       Back Squat  Clean and Jerk  Deadlift Fight Gone Bad  Filthy 50   Fran  \
# 0          140.0            90.0     190.0           322      1075.0  298.0
# 1            NaN             NaN       NaN            NaN        NaN    NaN
# 2          166.0           111.0     181.0            NaN        NaN    NaN
# 3            NaN             NaN       NaN            NaN        NaN    NaN
# 4          134.0           102.0     211.0           412      1049.0  172.0
# 5          107.0            82.0       NaN            NaN        NaN    NaN
# 6          160.0           125.0     200.0            NaN        NaN    NaN
# 7            NaN            51.0     119.0           269         NaN    NaN
# 8          120.0             NaN     138.0            NaN        NaN    NaN
# 9          125.0            79.0     129.0            NaN        NaN    NaN
# 10         184.0           120.0     206.0            NaN        NaN    NaN
# 11         125.0            86.0     175.0           344      1336.0  270.0
# 12         140.0           110.0     200.0            NaN        NaN    NaN
# 13         136.0           113.0     179.0            NaN        NaN    NaN
# 14         181.0           104.0     193.0            NaN        NaN  270.0
# 15         104.0            66.0       NaN            NaN        NaN    NaN
# 16         111.0            86.0     188.0           267         NaN  499.0
# 17           NaN            67.0      95.0            NaN        NaN  330.0
# 18         143.0            93.0     193.0           272      1394.0  324.0
# 19         129.0            86.0     156.0            NaN        NaN  350.0
# 20         205.0           130.0     220.0            NaN        NaN    NaN
# 21           NaN             NaN       NaN            NaN        NaN    NaN
# 22         125.0            93.0     152.0            NaN        NaN  291.0
# 23         111.0            93.0     175.0            NaN        NaN    NaN
# 24          79.0            52.0     102.0            NaN        NaN  576.0
# 25          93.0            77.0     125.0           310      1457.0  212.0
# 26           NaN             NaN       NaN            NaN     1941.0    NaN
# 27          91.0            66.0     107.0            NaN        NaN    NaN
# 28         111.0             NaN     147.0           259         NaN    NaN
# 29          98.0            66.0     102.0            NaN        NaN    NaN
# ...          ...             ...       ...            ...        ...    ...
# 7259         NaN             NaN       NaN            NaN        NaN    NaN
# 7260       175.0           116.0     211.0           405      1343.0  194.0
# 7261         NaN             NaN       NaN            NaN        NaN    NaN
# 7262       134.0             NaN     225.0            NaN        NaN    NaN
# 7263       111.0            77.0     125.0           331         NaN  319.0
# 7264       184.0           116.0     211.0           411       966.0  159.0
# 7265       195.0           129.0     247.0           320      1598.0  324.0
# 7266         NaN             NaN       NaN            NaN        NaN    NaN
# 7267       175.0           125.0       NaN            NaN        NaN    NaN
# 7268         NaN             NaN       NaN            NaN        NaN    NaN
# 7269         NaN             NaN       NaN            NaN        NaN    NaN
# 7270       147.0            79.0     138.0            NaN        NaN    NaN
# 7271       240.0             NaN     254.0            NaN        NaN    NaN
# 7272         NaN             NaN       NaN            NaN        NaN    NaN
# 7273       156.0           120.0     234.0            NaN     1165.0  186.0
# 7274         NaN             NaN       NaN            NaN        NaN    NaN
# 7275       102.0             NaN     129.0            NaN        NaN    NaN
# 7276         NaN             NaN       NaN            NaN        NaN    NaN
# 7277         NaN            90.0     180.0            NaN        NaN    NaN
# 7278         NaN             NaN       NaN            NaN        NaN    NaN
# 7279       156.0           118.0     206.0            NaN        NaN  275.0
# 7280         NaN             NaN     152.0            NaN        NaN    NaN
# 7281         NaN             NaN       NaN            NaN        NaN    NaN
# 7282         NaN             NaN       NaN            NaN        NaN    NaN
# 7283       114.0            68.0     122.0            NaN        NaN    NaN
# 7284       175.0           132.0     204.0           294      1937.0  200.0
# 7285       202.0           154.0     247.0           484         NaN  154.0
# 7286       150.0           111.0     181.0            NaN        NaN    NaN
# 7287         NaN             NaN       NaN            NaN        NaN    NaN
# 7288         NaN             NaN       NaN            NaN        NaN    NaN
#
#       Grace  Helen Max Pull-ups  Run 5k  Snatch  Sprint 400m  2008  2009  \
# 0     162.0  452.0          NaN    82.0    75.0          NaN   NaN   NaN
# 1       NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 2       NaN    NaN          NaN     NaN    79.0          NaN   NaN   NaN
# 3       NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 4     179.0  421.0          50   1201.0    75.0          NaN   NaN   NaN
# 5     166.0    NaN          NaN     NaN    66.0          NaN   NaN   NaN
# 6       NaN    NaN          NaN     NaN    95.0          NaN   NaN   NaN
# 7       NaN    NaN          NaN  1494.0     NaN          NaN   NaN   NaN
# 8       NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 9       NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 10      NaN    NaN          NaN     NaN    93.0          NaN   NaN   NaN
# 11    329.0  523.0          NaN     NaN     NaN          NaN   NaN   NaN
# 12      NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 13    227.0    NaN          NaN  1425.0    91.0          NaN   NaN   NaN
# 14    235.0    NaN          21      NaN     NaN          NaN   NaN   NaN
# 15      NaN    NaN          NaN     NaN    48.0          NaN   NaN   NaN
# 16    187.0  692.0          NaN  1336.0    66.0          NaN   NaN   NaN
# 17    321.0    NaN          10      NaN    50.0          NaN   NaN   NaN
# 18    178.0  667.0          NaN     NaN    75.0          NaN   NaN   NaN
# 19      NaN    NaN          30   1330.0    70.0          NaN   NaN   NaN
# 20      NaN    NaN          30   1315.0   101.0          NaN   NaN   NaN
# 21      NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 22    750.0    NaN          NaN     NaN    61.0          NaN   NaN   NaN
# 23      NaN  462.0          42      NaN    66.0          NaN   NaN   NaN
# 24      NaN    NaN          10      NaN    39.0          NaN   NaN   NaN
# 25    188.0  541.0          46   1302.0    57.0          NaN   NaN   NaN
# 26      NaN  778.0          NaN  1692.0     NaN         94.0   NaN   NaN
# 27      NaN    NaN           7      NaN    45.0          NaN   NaN   NaN
# 28      NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 29      NaN    NaN          10      NaN    52.0          NaN   NaN   NaN
# ...     ...    ...          ...     ...     ...          ...   ...   ...
# 7259    NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 7260  121.0  455.0          NaN  1230.0    98.0         57.0   NaN   NaN
# 7261    NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 7262    NaN    NaN          NaN     NaN    75.0          NaN   NaN   NaN
# 7263  150.0  620.0          14      NaN    48.0          NaN   NaN   NaN
# 7264   83.0  445.0          58      NaN    98.0         56.0   NaN   NaN
# 7265    NaN    NaN          NaN     NaN    84.0          NaN   NaN   NaN
# 7266    NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 7267    NaN    NaN          NaN     NaN    95.0          NaN   NaN   NaN
# 7268    NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 7269    NaN    NaN          15      NaN     NaN          NaN   NaN   NaN
# 7270    NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 7271    NaN    NaN          30      NaN     NaN          NaN   NaN   NaN
# 7272    NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 7273  104.0  521.0          46      NaN    95.0          NaN   NaN   NaN
# 7274    NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 7275    NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 7276    NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 7277    NaN    NaN          60      NaN    60.0        105.0   NaN   NaN
# 7278    NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 7279  138.0    NaN          30      NaN    88.0          NaN   NaN   NaN
# 7280    NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 7281    NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 7282    NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 7283  183.0    NaN          NaN     NaN    45.0          NaN   NaN   NaN
# 7284  133.0  600.0          NaN     NaN    98.0         72.0   NaN   NaN
# 7285   87.0  546.0          63   1140.0   134.0          NaN   NaN   NaN
# 7286    NaN    NaN          NaN     NaN    84.0         67.0   NaN   NaN
# 7287    NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
# 7288    NaN    NaN          NaN     NaN     NaN          NaN   NaN   NaN
#
#       2010  2011  2012     2013     2014     2015     2016  2017  \
# 0      NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 1      NaN   NaN   NaN   1591.0   1414.0    902.0    696.0   NaN
# 2      NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 3      NaN   NaN   NaN    460.0      NaN   1114.0      NaN   NaN
# 4      NaN   NaN   NaN      NaN  21848.0  15971.0  12094.0   NaN
# 5      NaN   NaN   NaN      NaN      NaN      NaN  28678.0   NaN
# 6      NaN   NaN   NaN      NaN  21165.0   6909.0   4968.0   NaN
# 7      NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 8      NaN   NaN   NaN      NaN      NaN      NaN   5011.0   NaN
# 9      NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 10     NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 11     NaN   NaN   NaN  11385.0  16027.0  28304.0  25863.0   NaN
# 12     NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 13     NaN   NaN   NaN  23344.0  27171.0      NaN  38048.0   NaN
# 14     NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 15     NaN   NaN   NaN   5277.0   8771.0   3729.0   4448.0   NaN
# 16     NaN   NaN   NaN      NaN  62473.0      NaN      NaN   NaN
# 17     NaN   NaN   NaN  10175.0      NaN  25251.0  35436.0   NaN
# 18     NaN   NaN   NaN   7804.0  11344.0      NaN      NaN   NaN
# 19     NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 20     NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 21     NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 22     NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 23     NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 24     NaN   NaN   NaN  11356.0  19694.0      NaN      NaN   NaN
# 25     NaN   NaN   NaN   2087.0      NaN   8841.0   4094.0   NaN
# 26     NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 27     NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 28     NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 29     NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# ...    ...   ...   ...      ...      ...      ...      ...   ...
# 7259   NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 7260   NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 7261   NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 7262   NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 7263   NaN   NaN   NaN  14004.0  13440.0  13141.0  10300.0   NaN
# 7264   NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 7265   NaN   NaN   NaN      NaN      NaN      NaN  38525.0   NaN
# 7266   NaN   NaN   NaN   1289.0      NaN   1024.0    607.0   NaN
# 7267   NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 7268   NaN   NaN   NaN   3490.0   6148.0   3198.0   4396.0   NaN
# 7269   NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 7270   NaN   NaN   NaN  10521.0  37228.0  25972.0  27441.0   NaN
# 7271   NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 7272   NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 7273   NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 7274   NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 7275   NaN   NaN   NaN      NaN      NaN  25761.0  32598.0   NaN
# 7276   NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 7277   NaN   NaN   NaN      NaN      NaN      NaN   6469.0   NaN
# 7278   NaN   NaN   NaN      NaN      NaN    970.0      NaN   NaN
# 7279   NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 7280   NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 7281   NaN   NaN   NaN   5815.0   7693.0      NaN      NaN   NaN
# 7282   NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 7283   NaN   NaN   NaN  10826.0  21697.0      NaN      NaN   NaN
# 7284   NaN   NaN   NaN      NaN  59008.0  24955.0  16866.0   NaN
# 7285   NaN   NaN   NaN   2193.0   5484.0    863.0      NaN   NaN
# 7286   NaN   NaN   NaN      NaN      NaN      NaN      NaN   NaN
# 7287   NaN   NaN   NaN      NaN  21281.0  28996.0      NaN   NaN
# 7288   NaN   NaN   NaN      NaN  23349.0  20165.0      NaN   NaN
#
#                      Affiliate  Age               Division  Height  \
# 0                          NaN   35                    NaN  180.00
# 1               CrossFit Big D   47    Masters Men (45-49)  167.64
# 2          CrossFit Ibirapuera   40    Masters Men (35-39)     NaN
# 3                 CrossFit 253   51    Masters Men (50-54)   12.70
# 4           CrossFit Manitowoc   39    Masters Men (35-39)  182.88
# 5         CrossFit Oregon City   39  Masters Women (35-39)  175.26
# 6             CrossFit Marilia   32         Individual Men  190.00
# 7                          NaN   31                    NaN  167.64
# 8                 Unaffiliated   36  Masters Women (35-39)  162.56
# 9                          NaN   60                    NaN  182.88
# 10                         NaN   24                    NaN     NaN
# 11                CrossFit 859   39    Masters Men (35-39)  185.42
# 12                         NaN   33                    NaN  182.00
# 13           CrossFit Illumine   36    Masters Men (35-39)  182.88
# 14                         NaN   34         Individual Men  182.88
# 15                Unaffiliated   32       Individual Women  162.00
# 16                Unaffiliated   34         Individual Men  195.58
# 17                Unaffiliated   38  Masters Women (35-39)  173.00
# 18            CrossFit Endzone   41    Masters Men (40-44)  180.34
# 19                         NaN   31                    NaN  167.64
# 20                         NaN   33                    NaN  175.00
# 21                         NaN   32                    NaN     NaN
# 22                         NaN   30                    NaN  175.26
# 23                         NaN   42                    NaN  177.80
# 24       Big Thompson CrossFit   28       Individual Women  162.56
# 25               CrossFit Ammo   35  Masters Women (35-39)  172.72
# 26            CrossFit Uncanny   39    Masters Men (35-39)  172.72
# 27                         NaN   31                    NaN  169.00
# 28                         NaN   27                    NaN  167.64
# 29             CrossFit Derive   30       Individual Women  160.02
# ...                        ...  ...                    ...     ...
# 7259                       NaN   30                    NaN  178.00
# 7260                       NaN   29                    NaN  180.34
# 7261                       NaN   36                    NaN  187.96
# 7262                       NaN   26                    NaN  190.50
# 7263        Post Road CrossFit   31       Individual Women  162.56
# 7264                       NaN   43                    NaN  177.80
# 7265          CrossFit Naptown   36    Masters Men (35-39)   15.24
# 7266             CrossFit Diem   49  Masters Women (45-49)  165.10
# 7267                       NaN   26                    NaN  182.88
# 7268           CrossFit Mantra   48    Masters Men (45-49)  177.80
# 7269                       NaN   40                    NaN  165.10
# 7270     CrossFit Cool Springs   35       Individual Women  165.10
# 7271                       NaN   23                    NaN  182.88
# 7272                       NaN   32                    NaN  195.00
# 7273                       NaN   29                    NaN  180.34
# 7274                       NaN   27                    NaN     NaN
# 7275         CrossFit Junction   33       Individual Women     NaN
# 7276                       NaN   40                    NaN  180.00
# 7277  Reebok CrossFit Spectrum   27         Individual Men  182.88
# 7278              CrossFit 956   53  Masters Women (50-54)     NaN
# 7279                       NaN   41                    NaN  180.34
# 7280                       NaN   23                    NaN  182.88
# 7281          Kiss My CrossFit   39  Masters Women (35-39)  172.72
# 7282         Practice CrossFit   35         Individual Men     NaN
# 7283         CrossFit Squamish   33       Individual Women   15.24
# 7284              CrossFit RTR   20         Individual Men  180.34
# 7285         Comanche CrossFit   32         Individual Men  182.88
# 7286                       NaN   44                    NaN  190.50
# 7287        CrossFit RepScheme   32         Individual Men  175.26
# 7288           CrossFit Nashua   39       Individual Women  172.72
#
#                            Name               Region  \
# 0                 Linus Mansson                  NaN
# 1                  Richard Neal        South Central
# 2                 Leandro Leite        Latin America
# 3                  Todd Burgess           North West
# 4                  Matt DiMarco        North Central
# 5                 Jen Cereghino           North West
# 6                  Robson Silva        Latin America
# 7              Mackenzie Aubrey                  NaN
# 8                Melyssa Gagnon          Canada East
# 9                  Jim McCarthy                  NaN
# 10              Anthoni Alberti                  NaN
# 11                   Eric Karls         Central East
# 12                Andy Mitchell                  NaN
# 13               Scott Kowalski        North Central
# 14                 Shaun Kimack         Mid Atlantic
# 15               Giannina Dongo        Latin America
# 16               William Miller         Central East
# 17              Claire Campbell            Australia
# 18                    Jon Adams  Northern California
# 19              Vincent Quintin                  NaN
# 20                 Tony Fontana                  NaN
# 21               Jenny Gonzalez                  NaN
# 22                Matt Williams                  NaN
# 23               Ryan Golphenee                  NaN
# 24               Mercedes Welte           South West
# 25                Erin Hathaway        South Central
# 26                 Steven Kwong           South East
# 27             Emilie Pettersen                  NaN
# 28                    Jojo Hall                  NaN
# 29               Paige Kennemer        South Central
# ...                         ...                  ...
# 7259            Bader Albedaiwi                  NaN
# 7260               Jules Renner                  NaN
# 7261             Stephen Molina                  NaN
# 7262             Steve Williams                  NaN
# 7263               Brittany Gee           North East
# 7264               Josh Coleson                  NaN
# 7265                Andy Miller         Central East
# 7266             Tracy Peterson        North Central
# 7267                Ryan Loftus                  NaN
# 7268              James Robatin         Central East
# 7269  alexandre bergeron ouimet                  NaN
# 7270          Michelle Robinson         Central East
# 7271            Jack St.Germain                  NaN
# 7272              Mathieu LEROY                  NaN
# 7273            Jake Laudermilk                  NaN
# 7274                Sarah Safir                  NaN
# 7275                Katie Sweet           South West
# 7276            Yoshihisa Ikeda                  NaN
# 7277               Grant Dillon               Europe
# 7278              Kimberly Berg          Canada West
# 7279           Micah Hartsfield                  NaN
# 7280                Bryce Vance                  NaN
# 7281              Bertha Garcia        South Central
# 7282             Ben Poeppelman         Central East
# 7283               Samantha Cox          Canada West
# 7284                Jacob McVay           South East
# 7285             David Pertuset         Central East
# 7286               Ryan Plosker                  NaN
# 7287             Marlon Miranda  Southern California
# 7288          Jennifer Bergeron           North East
#
#                                          Team  Weight  gender
# 0                                         NaN    79.0    None
# 1                              CrossFit Big D    66.0    Male
# 2                                         NaN    91.0    Male
# 3                                         NaN    81.0    Male
# 4                          CrossFit Manitowoc    86.0    Male
# 5                                        CFOC    65.0  Female
# 6                                         NaN    93.0    Male
# 7                                         NaN    69.0    None
# 8                                         NaN    52.0  Female
# 9                                         NaN   102.0    None
# 10                                        NaN     NaN    None
# 11                                        NaN    79.0    Male
# 12                                        NaN    95.0    None
# 13                                        NaN    91.0    Male
# 14                                        NaN    93.0    Male
# 15                             CrossFit Aukka    59.0  Female
# 16                                        NaN   118.0    Male
# 17    Brunswick East CrossFit - Just for fun!    73.0  Female
# 18                           CrossFit Endzone   100.0    Male
# 19                                        NaN    68.0    None
# 20                                        NaN     NaN    None
# 21                                        NaN     NaN    None
# 22                                        NaN    75.0    None
# 23                                        NaN    84.0    None
# 24                      Big Thompson CrossFit    66.0  Female
# 25                              CrossFit Ammo    62.0  Female
# 26                            Uncanny Fitness    75.0    Male
# 27                                        NaN    66.0    None
# 28                                        NaN    78.0    None
# 29                                Team Derive    75.0  Female
# ...                                       ...     ...     ...
# 7259                                      NaN     NaN    None
# 7260                                      NaN    88.0    None
# 7261                                      NaN   111.0    None
# 7262                                      NaN    88.0    None
# 7263                       Post Road CrossFit    63.0  Female
# 7264                                      NaN    87.0    None
# 7265                                      NaN   111.0    Male
# 7266                                      NaN    59.0  Female
# 7267                                      NaN    94.0    None
# 7268                          CrossFit Mantra    95.0    Male
# 7269                                      NaN    69.0    None
# 7270                                      NaN    77.0  Female
# 7271                                      NaN   104.0    None
# 7272                                      NaN    95.0    None
# 7273                                      NaN    91.0    None
# 7274                                      NaN     NaN    None
# 7275                        CFJ Team Tenacity     NaN  Female
# 7276                                      NaN    84.0    None
# 7277                                      NaN    86.0    Male
# 7278                                      NaN     NaN  Female
# 7279                                      NaN    98.0    None
# 7280                                      NaN    84.0    None
# 7281                         Kiss My CrossFit    77.0  Female
# 7282                        Practice CrossFit     NaN    Male
# 7283                                      NaN    80.0  Female
# 7284                             CrossFit RTR    83.0    Male
# 7285                        Comanche CrossFit    95.0    Male
# 7286                                      NaN    95.0    None
# 7287                                      NaN    79.0    Male
# 7288                          CrossFit Nashua    61.0  Female
#
# [7289 rows x 31 columns]

# %% [markdown]
# ## 3. Output cleansed data

# %%
df.to_csv(r'C:\Users\suhaib.qazi\Desktop\CF_data_cleansed.csv', sep=',')
